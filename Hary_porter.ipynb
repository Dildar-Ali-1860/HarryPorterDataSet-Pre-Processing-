# %%
import pandas as pd

# %%
hary = pd.read_csv('Harry_Potter_Scraped_Dataset.csv')

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Publish Date Publish Month  Publish Year  Pages  \
# 0                    120            26          June          1997    223
# 1                     77             2          July          1998    251
# 2                     65             8          July          1999    317
# 3                     65             8          July          2000    636
# 4                     65            21          June          2003    766
# ...

# %%
hary.head()
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
#
#    Copies Sold WorldWide  Publish Date Publish Month  Publish Year  Pages  \
# 0                    120            26          June          1997    223
# 1                     77             2          July          1998    251
# 2                     65             8          July          1999    317
# 3                     65             8          July          2000    636
# 4                     65            21          June          2003    766
#
#      Words           Audiobook  Total Awards Won
# 0   76,944   9 hrs and 33 mins                 8
# ...

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Publish Date Publish Month  Publish Year  Pages  \
# 0                    120            26          June          1997    223
# 1                     77             2          July          1998    251
# 2                     65             8          July          1999    317
# 3                     65             8          July          2000    636
# 4                     65            21          June          2003    766
# ...

# %%
hary.Words = hary.Words.str.replace(',','')

# %%
hary = hary.rename(columns={'Total Awards Won':'Awards'})

# %%
hary.Awards.unique()
# Out:
# array([8, 5, 3, 1, 0], dtype=int64)

# %%
hary.Awards.sum()
# Out:
# 19

# %%
hary.Pages.unique()
# Out:
# array([223, 251, 317, 636, 766, 607], dtype=int64)

# %%
hary.drop(['Awards'],inplace=True,axis=1)

# %%
hary.columns
# Out:
# Index(['Book Name', 'Copies Sold in UK', 'Copies Sold WorldWide',
#        'Publish Date', 'Publish Month', 'Publish Year', 'Pages', 'Words',
#        'Audiobook'],
#       dtype='object')

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Publish Date Publish Month  Publish Year  Pages  \
# 0                    120            26          June          1997    223
# 1                     77             2          July          1998    251
# 2                     65             8          July          1999    317
# 3                     65             8          July          2000    636
# 4                     65            21          June          2003    766
# ...

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Publish Date Publish Month  Publish Year  Pages  \
# 0                    120            26          June          1997    223
# 1                     77             2          July          1998    251
# 2                     65             8          July          1999    317
# 3                     65             8          July          2000    636
# 4                     65            21          June          2003    766
# ...

# %%
hary = hary.rename(columns={'Publish Date':'Date'})

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Date Publish Month  Publish Year  Pages   Words  \
# 0                    120    26          June          1997    223   76944
# 1                     77     2          July          1998    251   85141
# 2                     65     8          July          1999    317  107253
# 3                     65     8          July          2000    636  190637
# 4                     65    21          June          2003    766  257045
# ...

# %%
hary.Audiobook = hary.Audiobook.str.replace('and',':')

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Date Publish Month  Publish Year  Pages   Words  \
# 0                    120    26          June          1997    223   76944
# 1                     77     2          July          1998    251   85141
# 2                     65     8          July          1999    317  107253
# 3                     65     8          July          2000    636  190637
# 4                     65    21          June          2003    766  257045
# ...

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Date Publish Month  Publish Year  Pages   Words  \
# 0                    120    26          June          1997    223   76944
# 1                     77     2          July          1998    251   85141
# 2                     65     8          July          1999    317  107253
# 3                     65     8          July          2000    636  190637
# 4                     65    21          June          2003    766  257045
# ...

# %%
hary = hary.rename(columns={'Publish Month':'Month'})

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Date Month  Publish Year  Pages   Words  \
# 0                    120    26  June          1997    223   76944
# 1                     77     2  July          1998    251   85141
# 2                     65     8  July          1999    317  107253
# 3                     65     8  July          2000    636  190637
# 4                     65    21  June          2003    766  257045
# ...

# %%
hary.Month.unique()
# Out:
# array(['June', 'July'], dtype=object)

# %%
hary.Month.count()
# Out:
# 7

# %%
hary.Month = hary.Month.replace('June','Feb')

# %%
hary = hary.rename(columns={'Publish Year':'Year'})

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Date Month  Year  Pages   Words         Audiobook
# 0                    120    26   Feb  1997    223   76944   9 hrs : 33 mins
# 1                     77     2  July  1998    251   85141   11 hrs : 5 mins
# 2                     65     8  July  1999    317  107253  13 hrs : 10 mins
# 3                     65     8  July  2000    636  190637  22 hrs : 17 mins
# ...

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Date Month  Year  Pages   Words         Audiobook
# 0                    120    26   Feb  1997    223   76944   9 hrs : 33 mins
# 1                     77     2  July  1998    251   85141   11 hrs : 5 mins
# 2                     65     8  July  1999    317  107253  13 hrs : 10 mins
# 3                     65     8  July  2000    636  190637  22 hrs : 17 mins
# ...

# %%
hary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Book Name              7 non-null      object
#  1   Copies Sold in UK      7 non-null      float64
#  2   Copies Sold WorldWide  7 non-null      int64
#  3   Date                   7 non-null      int64
#  4   Month                  7 non-null      object
#  5   Year                   7 non-null      int64
#  6   Pages                  7 non-null      int64
#  7   Words                  7 non-null      object
#  8   Audiobook              7 non-null      object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 632.0+ bytes

# %%
hary.Date.iloc[0] = 2022
# Out:
# C:\Users\iam18\AppData\Local\Temp\ipykernel_2412\2283970492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hary.Date.iloc[0] = 2022

# %%
hary
# Out:
#                                    Book Name  Copies Sold in UK  \
# 0      Harry Potter and the Sorcerer’s Stone                4.2
# 1    Harry Potter and the Chamber of Secrets                3.5
# 2   Harry Potter and the Prisoner of Azkaban                3.4
# 3        Harry Potter and the Goblet of Fire                3.6
# 4  Harry Potter and the Order of the Phoenix                4.2
# 5     Harry Potter and the Half-blood Prince                4.1
# 6       Harry Potter and the Deathly Hallows                4.5
#
#    Copies Sold WorldWide  Date Month  Year  Pages   Words         Audiobook
# 0                    120  2022   Feb  1997    223   76944   9 hrs : 33 mins
# 1                     77     2  July  1998    251   85141   11 hrs : 5 mins
# 2                     65     8  July  1999    317  107253  13 hrs : 10 mins
# 3                     65     8  July  2000    636  190637  22 hrs : 17 mins
# ...
